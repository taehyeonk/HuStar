# %%
import numpy as np
import pandas as pd
import pickle

# %% [markdown]
# ## 실습 내용

# %% [markdown]
# ## 1. Jupyter notebook basic
# 자주 사용 하는 단축키들

# %% [markdown]
# ##  주석 1

# %%
# esc: command mode
# entder: edit mode
# h: help

# Command mode
# a: 위에 셀 추가
# b: 아래 셀 추가
# o: 결과창 숨기기

# edit mode
# ctrl + shift + - : 현재 기준으로 셀 나누기

# cell type
# m: markdown
# c: cell

# %% [markdown]
# ## 2. Pandas

# %% [markdown]
# ### 2.1 파일 불러들이기

# %%
#jupyter notebook 상에서 library 설치
# !pip install xlrd
# Out:
# ...
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\smarthinj\anaconda3\envs\smarthinj\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\smarthinj\anaconda3\envs\smarthinj\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\smarthinj\anaconda3\envs\smarthinj\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\smarthinj\anaconda3\envs\smarthinj\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\smarthinj\anaconda3\envs\smarthinj\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\smarthinj\anaconda3\envs\smarthinj\lib\site-packages)
# WARNING: You are using pip version 21.1.1; however, version 21.1.3 is available.
# You should consider upgrading via the 'c:\users\smarthinj\anaconda3\envs\smarthinj\python.exe -m pip install --upgrade pip' command.

# %%
df = pd.read_csv('./Dataset/dataset_city.csv')

# %%
type(df) #EQ의 자료형 확인
# Out:
# pandas.core.frame.DataFrame

# %%
# ctrl + enter: 현재 셀만 실행
# alt + enter : 현재 셀 실행 후 아래에 새로운 셀 추가
# shift + enter : 현재 셀 실행 후 아래 셀로 이동

# %%
df
# Out:
#                  col1              col2   col3   col4  col5   col6   col7  \
# 0           Ahmedabad   2015-01-01 1:00    NaN    NaN  1.00  40.01  36.37
# 1           Ahmedabad   2015-01-01 2:00    NaN    NaN  0.02  27.75  19.73
# 2           Ahmedabad   2015-01-01 3:00    NaN    NaN  0.08  19.32  11.08
# 3           Ahmedabad   2015-01-01 4:00    NaN    NaN  0.30  16.45   9.20
# 4           Ahmedabad   2015-01-01 5:00    NaN    NaN  0.12  14.90   7.85
# ...               ...               ...    ...    ...   ...    ...    ...
# 670825  Visakhapatnam  2020-06-30 20:00   9.50  36.00  2.75  25.57  15.85
# 670826  Visakhapatnam  2020-06-30 21:00  17.25  49.25  3.62  33.20  20.62
# 670827  Visakhapatnam  2020-06-30 22:00  36.00  71.00  2.20  30.80  18.20
# 670828  Visakhapatnam  2020-06-30 23:00  15.75  63.00  1.02  28.90  16.00
# 670829  Visakhapatnam   2020-07-01 0:00  15.00  66.00  0.40  26.85  14.05
#
#         col8  col9   col10   col11  col12  col13  col14  col15         col16
# ...

# %% [markdown]
# ### 2.2 pandas dataframe 살펴보기

# %%
# ?df.head

# %%
df.head(5) #처음 5개 row 살펴보기
# Out:
#         col1             col2  col3  col4  col5   col6   col7  col8  col9  \
# 0  Ahmedabad  2015-01-01 1:00   NaN   NaN  1.00  40.01  36.37   NaN  1.00
# 1  Ahmedabad  2015-01-01 2:00   NaN   NaN  0.02  27.75  19.73   NaN  0.02
# 2  Ahmedabad  2015-01-01 3:00   NaN   NaN  0.08  19.32  11.08   NaN  0.08
# 3  Ahmedabad  2015-01-01 4:00   NaN   NaN  0.30  16.45   9.20   NaN  0.30
# 4  Ahmedabad  2015-01-01 5:00   NaN   NaN  0.12  14.90   7.85   NaN  0.12
#
#     col10   col11  col12  col13  col14  col15 col16
# 0  122.07     NaN    0.0    0.0    0.0    NaN   NaN
# 1   85.90     NaN    0.0    0.0    0.0    NaN   NaN
# 2   52.83     NaN    0.0    0.0    0.0    NaN   NaN
# 3   39.53  153.58    0.0    0.0    0.0    NaN   NaN
# 4   32.63     NaN    0.0    0.0    0.0    NaN   NaN

# %%
df['col2']
# Out:
# 0          2015-01-01 1:00
# 1          2015-01-01 2:00
# 2          2015-01-01 3:00
# 3          2015-01-01 4:00
# 4          2015-01-01 5:00
#                 ...
# 670825    2020-06-30 20:00
# 670826    2020-06-30 21:00
# 670827    2020-06-30 22:00
# 670828    2020-06-30 23:00
# 670829     2020-07-01 0:00
# Name: col2, Length: 670830, dtype: object

# %%
# loc: label을 이용하여 접근
df.loc[0:2,'col3':'col6']
# Out:
#    col3  col4  col5   col6
# 0   NaN   NaN  1.00  40.01
# 1   NaN   NaN  0.02  27.75
# 2   NaN   NaN  0.08  19.32

# %%
df.loc[:5,:'col4']
# Out:
#         col1             col2  col3  col4
# 0  Ahmedabad  2015-01-01 1:00   NaN   NaN
# 1  Ahmedabad  2015-01-01 2:00   NaN   NaN
# 2  Ahmedabad  2015-01-01 3:00   NaN   NaN
# 3  Ahmedabad  2015-01-01 4:00   NaN   NaN
# 4  Ahmedabad  2015-01-01 5:00   NaN   NaN
# 5  Ahmedabad  2015-01-01 6:00   NaN   NaN

# %%
df.loc[:,'col2':'col3']
# Out:
#                     col2   col3
# 0        2015-01-01 1:00    NaN
# 1        2015-01-01 2:00    NaN
# 2        2015-01-01 3:00    NaN
# 3        2015-01-01 4:00    NaN
# 4        2015-01-01 5:00    NaN
# ...                  ...    ...
# 670825  2020-06-30 20:00   9.50
# 670826  2020-06-30 21:00  17.25
# 670827  2020-06-30 22:00  36.00
# 670828  2020-06-30 23:00  15.75
# 670829   2020-07-01 0:00  15.00
#
# [670830 rows x 2 columns]

# %%
# iloc: 위치 정수를 통한 접근
df.iloc[:2,:]
# Out:
#         col1             col2  col3  col4  col5   col6   col7  col8  col9  \
# 0  Ahmedabad  2015-01-01 1:00   NaN   NaN  1.00  40.01  36.37   NaN  1.00
# 1  Ahmedabad  2015-01-01 2:00   NaN   NaN  0.02  27.75  19.73   NaN  0.02
#
#     col10  col11  col12  col13  col14  col15 col16
# 0  122.07    NaN    0.0    0.0    0.0    NaN   NaN
# 1   85.90    NaN    0.0    0.0    0.0    NaN   NaN

# %%
df.iloc[2:4,1:4]
# Out:
#               col2  col3  col4
# 2  2015-01-01 3:00   NaN   NaN
# 3  2015-01-01 4:00   NaN   NaN

# %%
df.iloc[:5,:2]
# Out:
#         col1             col2
# 0  Ahmedabad  2015-01-01 1:00
# 1  Ahmedabad  2015-01-01 2:00
# 2  Ahmedabad  2015-01-01 3:00
# 3  Ahmedabad  2015-01-01 4:00
# 4  Ahmedabad  2015-01-01 5:00

# %%
#  변수 형태 살펴보기
df.dtypes
# Out:
# col1      object
# col2      object
# col3     float64
# col4     float64
# col5     float64
# col6     float64
# col7     float64
# col8     float64
# col9     float64
# col10    float64
# col11    float64
# col12    float64
# col13    float64
# col14    float64
# col15    float64
# col16     object
# dtype: object

# %%
# 요약
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 670830 entries, 0 to 670829
# Data columns (total 16 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   col1    670830 non-null  object
#  1   col2    670830 non-null  object
#  2   col3    530858 non-null  float64
#  3   col4    380931 non-null  float64
#  4   col5    558625 non-null  float64
#  5   col6    557935 non-null  float64
#  6   col7    551494 non-null  float64
#  7   col8    407200 non-null  float64
#  8   col9    586398 non-null  float64
#  9   col10   543891 non-null  float64
#  10  col11   547372 non-null  float64
#  11  col12   515584 non-null  float64
#  12  col13   460298 non-null  float64
#  13  col14   243501 non-null  float64
#  14  col15   545725 non-null  float64
#  15  col16   545725 non-null  object
# dtypes: float64(13), object(3)
# memory usage: 81.9+ MB

# %%
df.describe()
# Out:
#                 col3           col4           col5           col6  \
# count  530858.000000  380931.000000  558625.000000  557935.000000
# mean       70.067364     124.037024      17.813423      29.589279
# std        76.084568     105.663468      32.702488      29.593462
# min         0.010000       0.010000       0.010000       0.010000
# 25%        27.750000      56.610000       3.900000      11.110000
# 50%        48.500000      94.890000       8.080000      21.000000
# 75%        82.250000     153.100000      16.450000      37.220000
# max       999.990000    1000.000000     499.990000     499.510000
#
#                 col7           col8           col9          col10  \
# count  551494.000000  407200.000000  586398.000000  543891.000000
# mean       32.957969      24.268378       2.265773      14.312244
# std        40.536889      29.545867      11.286639      19.788800
# min         0.000000       0.010000       0.000000       0.010000
# ...

# %%
df['col3'].mean()
# Out:
# 70.06736366410603

# %%
df['col3'].std()
# Out:
# 76.08456799269976

# %% [markdown]
# ### 2.3 특정 조건에 행이나 열 선택하기

# %%
df
# Out:
#                  col1              col2   col3   col4  col5   col6   col7  \
# 0           Ahmedabad   2015-01-01 1:00    NaN    NaN  1.00  40.01  36.37
# 1           Ahmedabad   2015-01-01 2:00    NaN    NaN  0.02  27.75  19.73
# 2           Ahmedabad   2015-01-01 3:00    NaN    NaN  0.08  19.32  11.08
# 3           Ahmedabad   2015-01-01 4:00    NaN    NaN  0.30  16.45   9.20
# 4           Ahmedabad   2015-01-01 5:00    NaN    NaN  0.12  14.90   7.85
# ...               ...               ...    ...    ...   ...    ...    ...
# 670825  Visakhapatnam  2020-06-30 20:00   9.50  36.00  2.75  25.57  15.85
# 670826  Visakhapatnam  2020-06-30 21:00  17.25  49.25  3.62  33.20  20.62
# 670827  Visakhapatnam  2020-06-30 22:00  36.00  71.00  2.20  30.80  18.20
# 670828  Visakhapatnam  2020-06-30 23:00  15.75  63.00  1.02  28.90  16.00
# 670829  Visakhapatnam   2020-07-01 0:00  15.00  66.00  0.40  26.85  14.05
#
#         col8  col9   col10   col11  col12  col13  col14  col15         col16
# ...

# %%
# 열 'D4'가 13인 것들만 선택하기
idx1 = df['col5']>=1
print(idx1)
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 670825     True
# 670826     True
# 670827     True
# 670828     True
# 670829    False
# Name: col5, Length: 670830, dtype: bool

# %%
df[idx1]
# Out:
#                  col1              col2   col3   col4  col5   col6   col7  \
# 0           Ahmedabad   2015-01-01 1:00    NaN    NaN  1.00  40.01  36.37
# 7           Ahmedabad   2015-01-01 8:00    NaN    NaN  1.03  16.66  16.48
# 8           Ahmedabad   2015-01-01 9:00    NaN    NaN  1.47  16.25  18.02
# 9           Ahmedabad  2015-01-01 10:00    NaN    NaN  2.05  13.78  16.08
# 10          Ahmedabad  2015-01-01 11:00    NaN    NaN  2.27  13.87  16.73
# ...               ...               ...    ...    ...   ...    ...    ...
# 670823  Visakhapatnam  2020-06-30 18:00   6.50  24.75  2.25  23.38  13.68
# 670825  Visakhapatnam  2020-06-30 20:00   9.50  36.00  2.75  25.57  15.85
# 670826  Visakhapatnam  2020-06-30 21:00  17.25  49.25  3.62  33.20  20.62
# 670827  Visakhapatnam  2020-06-30 22:00  36.00  71.00  2.20  30.80  18.20
# 670828  Visakhapatnam  2020-06-30 23:00  15.75  63.00  1.02  28.90  16.00
#
#          col8  col9   col10   col11  col12  col13  col14  col15         col16
# ...

# %%
idx2 = (df['col5']>=1 ) & (df['col9']<=0.5)
df[idx2]
# Out:
#                  col1              col2   col3    col4   col5   col6   col7  \
# 46224       Ahmedabad   2020-04-10 1:00  68.81  136.03   5.23  39.01  22.93
# 46225       Ahmedabad   2020-04-10 2:00  60.53  124.78   3.83  22.58  13.87
# 46226       Ahmedabad   2020-04-10 3:00  43.08  105.17   3.94  17.66  11.55
# 46227       Ahmedabad   2020-04-10 4:00  35.20   90.28   5.67  24.95  16.41
# 46231       Ahmedabad   2020-04-10 8:00  23.55   63.03   8.29  18.92  15.42
# ...               ...               ...    ...     ...    ...    ...    ...
# 670810  Visakhapatnam   2020-06-30 5:00  13.50   44.75   6.60  35.15  24.05
# 670811  Visakhapatnam   2020-06-30 6:00  15.00   50.00  15.45  36.88  32.20
# 670819  Visakhapatnam  2020-06-30 14:00  10.75   36.75   1.10  17.75  10.28
# 670821  Visakhapatnam  2020-06-30 16:00  14.00   29.50   1.77  20.70  12.45
# 670828  Visakhapatnam  2020-06-30 23:00  15.75   63.00   1.02  28.90  16.00
#
# ...

# %%
idx3 = (df['col5']>=1 ) |(df['col9']<=0.5)
df[idx3]
# Out:
#                  col1              col2   col3   col4  col5   col6   col7  \
# 0           Ahmedabad   2015-01-01 1:00    NaN    NaN  1.00  40.01  36.37
# 1           Ahmedabad   2015-01-01 2:00    NaN    NaN  0.02  27.75  19.73
# 2           Ahmedabad   2015-01-01 3:00    NaN    NaN  0.08  19.32  11.08
# 3           Ahmedabad   2015-01-01 4:00    NaN    NaN  0.30  16.45   9.20
# 4           Ahmedabad   2015-01-01 5:00    NaN    NaN  0.12  14.90   7.85
# ...               ...               ...    ...    ...   ...    ...    ...
# 670824  Visakhapatnam  2020-06-30 19:00   8.25  33.25  0.35  24.05  13.05
# 670825  Visakhapatnam  2020-06-30 20:00   9.50  36.00  2.75  25.57  15.85
# 670826  Visakhapatnam  2020-06-30 21:00  17.25  49.25  3.62  33.20  20.62
# 670827  Visakhapatnam  2020-06-30 22:00  36.00  71.00  2.20  30.80  18.20
# 670828  Visakhapatnam  2020-06-30 23:00  15.75  63.00  1.02  28.90  16.00
#
#         col8  col9   col10   col11  col12  col13  col14  col15         col16
# ...

# %%
df.dtypes
# Out:
# col1      object
# col2      object
# col3     float64
# col4     float64
# col5     float64
# col6     float64
# col7     float64
# col8     float64
# col9     float64
# col10    float64
# col11    float64
# col12    float64
# col13    float64
# col14    float64
# col15    float64
# col16     object
# dtype: object

# %%
# 변수 형태가 object (문자열 포함)인 열만 선택하기
idx4 = df.dtypes=='object'
print(idx4)
# Out:
# col1      True
# col2      True
# col3     False
# col4     False
# col5     False
# col6     False
# col7     False
# col8     False
# col9     False
# col10    False
# col11    False
# col12    False
# col13    False
# col14    False
# col15    False
# col16     True
# dtype: bool

# %%
df.loc[:,idx4]
# Out:
#                  col1              col2         col16
# 0           Ahmedabad   2015-01-01 1:00           NaN
# 1           Ahmedabad   2015-01-01 2:00           NaN
# 2           Ahmedabad   2015-01-01 3:00           NaN
# 3           Ahmedabad   2015-01-01 4:00           NaN
# 4           Ahmedabad   2015-01-01 5:00           NaN
# ...               ...               ...           ...
# 670825  Visakhapatnam  2020-06-30 20:00  Satisfactory
# 670826  Visakhapatnam  2020-06-30 21:00  Satisfactory
# 670827  Visakhapatnam  2020-06-30 22:00          Good
# 670828  Visakhapatnam  2020-06-30 23:00          Good
# 670829  Visakhapatnam   2020-07-01 0:00          Good
#
# [670830 rows x 3 columns]

# %%
df.describe()
# Out:
#                 col3           col4           col5           col6  \
# count  530858.000000  380931.000000  558625.000000  557935.000000
# mean       70.067364     124.037024      17.813423      29.589279
# std        76.084568     105.663468      32.702488      29.593462
# min         0.010000       0.010000       0.010000       0.010000
# 25%        27.750000      56.610000       3.900000      11.110000
# 50%        48.500000      94.890000       8.080000      21.000000
# 75%        82.250000     153.100000      16.450000      37.220000
# max       999.990000    1000.000000     499.990000     499.510000
#
#                 col7           col8           col9          col10  \
# count  551494.000000  407200.000000  586398.000000  543891.000000
# mean       32.957969      24.268378       2.265773      14.312244
# std        40.536889      29.545867      11.286639      19.788800
# min         0.000000       0.010000       0.000000       0.010000
# ...

# %% [markdown]
# #### 실습
# * 열 조건: 형태가 숫자형
#
# * 행 조건: 3열의 값이 평균 이상
#
# > 예: 'col3'>= df['col3'].mean()
#
# * 두 조건을 만족하는 데이터만 filter하기

# %%
idx_col = (df.dtypes=='float') | (df.dtypes=='int64')
idx_row = (df['col3']>=df['col3'].mean())

# %%
print(df.iloc[idx_row.array,idx_col.array])
# Out:
#           col3    col4   col5   col6    col7   col8   col9  col10  col11  \
# 668      81.30     NaN  23.23  47.66   75.67    NaN  23.23  50.19  30.83
# 669     105.53     NaN  43.73  45.93   94.58    NaN  43.73  31.99  53.83
# 670     118.33     NaN  39.17  43.69   87.27    NaN  39.17  44.06  42.88
# 671     119.40     NaN  61.20  42.79  107.30    NaN  61.20  20.02  12.62
# 672     137.43     NaN  11.02  41.19   52.90    NaN  11.02  38.24  28.25
# ...        ...     ...    ...    ...     ...    ...    ...    ...    ...
# 670382   71.00  143.00  26.22  60.15   53.30   9.25   1.11   1.40  18.48
# 670629   83.75  181.75   0.90  36.45   19.75  19.65   0.93  25.62  68.60
# 670677  126.50  185.50   2.77  33.22   19.93  26.65   1.52  17.98  28.48
# 670678  169.50  235.75   2.23  30.95   18.30  24.15   1.29  14.80  28.57
# 670679  107.75  161.50   1.82  21.62   12.53  16.45   0.54    NaN  28.80
#
#         col12  col13  col14  col15
# 668      0.27   0.00   5.82    NaN
# ...

# %%
# 두 pandas dataframe 합치기

df1 = df.loc[:,('col2','col4')]
df2 = df.loc[:,('col1','col3')]

# %%
df3 = pd.concat([df1,df2],axis=1)

# %%
df3
# Out:
#                     col2   col4           col1   col3
# 0        2015-01-01 1:00    NaN      Ahmedabad    NaN
# 1        2015-01-01 2:00    NaN      Ahmedabad    NaN
# 2        2015-01-01 3:00    NaN      Ahmedabad    NaN
# 3        2015-01-01 4:00    NaN      Ahmedabad    NaN
# 4        2015-01-01 5:00    NaN      Ahmedabad    NaN
# ...                  ...    ...            ...    ...
# 670825  2020-06-30 20:00  36.00  Visakhapatnam   9.50
# 670826  2020-06-30 21:00  49.25  Visakhapatnam  17.25
# 670827  2020-06-30 22:00  71.00  Visakhapatnam  36.00
# 670828  2020-06-30 23:00  63.00  Visakhapatnam  15.75
# 670829   2020-07-01 0:00  66.00  Visakhapatnam  15.00
#
# [670830 rows x 4 columns]

# %% [markdown]
# ### 2.4 결측치 처리 하기

# %%
df.head()
# Out:
#         col1             col2  col3  col4  col5   col6   col7  col8  col9  \
# 0  Ahmedabad  2015-01-01 1:00   NaN   NaN  1.00  40.01  36.37   NaN  1.00
# 1  Ahmedabad  2015-01-01 2:00   NaN   NaN  0.02  27.75  19.73   NaN  0.02
# 2  Ahmedabad  2015-01-01 3:00   NaN   NaN  0.08  19.32  11.08   NaN  0.08
# 3  Ahmedabad  2015-01-01 4:00   NaN   NaN  0.30  16.45   9.20   NaN  0.30
# 4  Ahmedabad  2015-01-01 5:00   NaN   NaN  0.12  14.90   7.85   NaN  0.12
#
#     col10   col11  col12  col13  col14  col15 col16
# 0  122.07     NaN    0.0    0.0    0.0    NaN   NaN
# 1   85.90     NaN    0.0    0.0    0.0    NaN   NaN
# 2   52.83     NaN    0.0    0.0    0.0    NaN   NaN
# 3   39.53  153.58    0.0    0.0    0.0    NaN   NaN
# 4   32.63     NaN    0.0    0.0    0.0    NaN   NaN

# %%
# nan이면 true 아니면 false
df.isnull()
# Out:
#          col1   col2   col3   col4   col5   col6   col7   col8   col9  col10  \
# 0       False  False   True   True  False  False  False   True  False  False
# 1       False  False   True   True  False  False  False   True  False  False
# 2       False  False   True   True  False  False  False   True  False  False
# 3       False  False   True   True  False  False  False   True  False  False
# 4       False  False   True   True  False  False  False   True  False  False
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 670825  False  False  False  False  False  False  False  False  False   True
# 670826  False  False  False  False  False  False  False  False  False  False
# 670827  False  False  False  False  False  False  False  False  False  False
# 670828  False  False  False  False  False  False  False  False  False  False
# 670829  False  False  False  False  False  False  False  False  False  False
#
# ...

# %%
# 각 행별 결측치 갯수
df.isnull().sum(1)
# Out:
# 0         6
# 1         6
# 2         6
# 3         5
# 4         6
#          ..
# 670825    4
# 670826    3
# 670827    3
# 670828    3
# 670829    3
# Length: 670830, dtype: int64

# %%
#각 열별 결측치 갯수
df.isnull().sum()
# Out:
# col1          0
# col2          0
# col3     139972
# col4     289899
# col5     112205
# col6     112895
# col7     119336
# col8     263630
# col9      84432
# col10    126939
# col11    123458
# col12    155246
# col13    210532
# col14    427329
# col15    125105
# col16    125105
# dtype: int64

# %%
idx5 = df.isnull().sum()<=200000
df.iloc[:,idx5.array]
# Out:
#                  col1              col2   col3  col5   col6   col7  col9  \
# 0           Ahmedabad   2015-01-01 1:00    NaN  1.00  40.01  36.37  1.00
# 1           Ahmedabad   2015-01-01 2:00    NaN  0.02  27.75  19.73  0.02
# 2           Ahmedabad   2015-01-01 3:00    NaN  0.08  19.32  11.08  0.08
# 3           Ahmedabad   2015-01-01 4:00    NaN  0.30  16.45   9.20  0.30
# 4           Ahmedabad   2015-01-01 5:00    NaN  0.12  14.90   7.85  0.12
# ...               ...               ...    ...   ...    ...    ...   ...
# 670825  Visakhapatnam  2020-06-30 20:00   9.50  2.75  25.57  15.85  0.62
# 670826  Visakhapatnam  2020-06-30 21:00  17.25  3.62  33.20  20.62  0.76
# 670827  Visakhapatnam  2020-06-30 22:00  36.00  2.20  30.80  18.20  0.58
# 670828  Visakhapatnam  2020-06-30 23:00  15.75  1.02  28.90  16.00  0.49
# 670829  Visakhapatnam   2020-07-01 0:00  15.00  0.40  26.85  14.05  0.59
#
#          col10   col11  col12  col15         col16
# ...

# %%
# 결측치를 모두 0으로 채우기
df.fillna(0)
# Out:
#                  col1              col2   col3   col4  col5   col6   col7  \
# 0           Ahmedabad   2015-01-01 1:00   0.00   0.00  1.00  40.01  36.37
# 1           Ahmedabad   2015-01-01 2:00   0.00   0.00  0.02  27.75  19.73
# 2           Ahmedabad   2015-01-01 3:00   0.00   0.00  0.08  19.32  11.08
# 3           Ahmedabad   2015-01-01 4:00   0.00   0.00  0.30  16.45   9.20
# 4           Ahmedabad   2015-01-01 5:00   0.00   0.00  0.12  14.90   7.85
# ...               ...               ...    ...    ...   ...    ...    ...
# 670825  Visakhapatnam  2020-06-30 20:00   9.50  36.00  2.75  25.57  15.85
# 670826  Visakhapatnam  2020-06-30 21:00  17.25  49.25  3.62  33.20  20.62
# 670827  Visakhapatnam  2020-06-30 22:00  36.00  71.00  2.20  30.80  18.20
# 670828  Visakhapatnam  2020-06-30 23:00  15.75  63.00  1.02  28.90  16.00
# 670829  Visakhapatnam   2020-07-01 0:00  15.00  66.00  0.40  26.85  14.05
#
#         col8  col9   col10   col11  col12  col13  col14  col15         col16
# ...

# %%
df.fillna(1)
# Out:
#                  col1              col2   col3   col4  col5   col6   col7  \
# 0           Ahmedabad   2015-01-01 1:00   1.00   1.00  1.00  40.01  36.37
# 1           Ahmedabad   2015-01-01 2:00   1.00   1.00  0.02  27.75  19.73
# 2           Ahmedabad   2015-01-01 3:00   1.00   1.00  0.08  19.32  11.08
# 3           Ahmedabad   2015-01-01 4:00   1.00   1.00  0.30  16.45   9.20
# 4           Ahmedabad   2015-01-01 5:00   1.00   1.00  0.12  14.90   7.85
# ...               ...               ...    ...    ...   ...    ...    ...
# 670825  Visakhapatnam  2020-06-30 20:00   9.50  36.00  2.75  25.57  15.85
# 670826  Visakhapatnam  2020-06-30 21:00  17.25  49.25  3.62  33.20  20.62
# 670827  Visakhapatnam  2020-06-30 22:00  36.00  71.00  2.20  30.80  18.20
# 670828  Visakhapatnam  2020-06-30 23:00  15.75  63.00  1.02  28.90  16.00
# 670829  Visakhapatnam   2020-07-01 0:00  15.00  66.00  0.40  26.85  14.05
#
#         col8  col9   col10   col11  col12  col13  col14  col15         col16
# ...

# %%
values = {'col3': 0, 'col4': 1}
df.fillna(value=values)
# Out:
#                  col1              col2   col3   col4  col5   col6   col7  \
# 0           Ahmedabad   2015-01-01 1:00   0.00   1.00  1.00  40.01  36.37
# 1           Ahmedabad   2015-01-01 2:00   0.00   1.00  0.02  27.75  19.73
# 2           Ahmedabad   2015-01-01 3:00   0.00   1.00  0.08  19.32  11.08
# 3           Ahmedabad   2015-01-01 4:00   0.00   1.00  0.30  16.45   9.20
# 4           Ahmedabad   2015-01-01 5:00   0.00   1.00  0.12  14.90   7.85
# ...               ...               ...    ...    ...   ...    ...    ...
# 670825  Visakhapatnam  2020-06-30 20:00   9.50  36.00  2.75  25.57  15.85
# 670826  Visakhapatnam  2020-06-30 21:00  17.25  49.25  3.62  33.20  20.62
# 670827  Visakhapatnam  2020-06-30 22:00  36.00  71.00  2.20  30.80  18.20
# 670828  Visakhapatnam  2020-06-30 23:00  15.75  63.00  1.02  28.90  16.00
# 670829  Visakhapatnam   2020-07-01 0:00  15.00  66.00  0.40  26.85  14.05
#
#         col8  col9   col10   col11  col12  col13  col14  col15         col16
# ...

# %%
# 연속형 변수를 평균으로 채우기
idx_contin = df.dtypes=='float64'
df_contin=df.loc[:,idx_contin]
print(df_contin)
df_contin_fill = df_contin.fillna(df_contin.mean())
print(df_contin_fill)
# Out:
#          col3   col4  col5   col6   col7  col8  col9   col10   col11  col12  \
# 0         NaN    NaN  1.00  40.01  36.37   NaN  1.00  122.07     NaN    0.0
# 1         NaN    NaN  0.02  27.75  19.73   NaN  0.02   85.90     NaN    0.0
# 2         NaN    NaN  0.08  19.32  11.08   NaN  0.08   52.83     NaN    0.0
# 3         NaN    NaN  0.30  16.45   9.20   NaN  0.30   39.53  153.58    0.0
# 4         NaN    NaN  0.12  14.90   7.85   NaN  0.12   32.63     NaN    0.0
# ...       ...    ...   ...    ...    ...   ...   ...     ...     ...    ...
# 670825   9.50  36.00  2.75  25.57  15.85  4.57  0.62     NaN   27.75    NaN
# 670826  17.25  49.25  3.62  33.20  20.62  3.78  0.76    2.02   25.58    NaN
# 670827  36.00  71.00  2.20  30.80  18.20  3.67  0.58    1.77   26.15    NaN
# 670828  15.75  63.00  1.02  28.90  16.00  3.80  0.49    0.75   15.82    NaN
# 670829  15.00  66.00  0.40  26.85  14.05  5.20  0.59    2.10   17.05    NaN
#
#         col13  col14  col15
# ...

# %%
# categorical 변수를 mode로 채우기
idx_cat = df.dtypes=='object'
df_cat = df.loc[:,idx_cat]
print(df_cat)
# Out:
#                  col1              col2         col16
# 0           Ahmedabad   2015-01-01 1:00           NaN
# 1           Ahmedabad   2015-01-01 2:00           NaN
# 2           Ahmedabad   2015-01-01 3:00           NaN
# 3           Ahmedabad   2015-01-01 4:00           NaN
# 4           Ahmedabad   2015-01-01 5:00           NaN
# ...               ...               ...           ...
# 670825  Visakhapatnam  2020-06-30 20:00  Satisfactory
# 670826  Visakhapatnam  2020-06-30 21:00  Satisfactory
# 670827  Visakhapatnam  2020-06-30 22:00          Good
# 670828  Visakhapatnam  2020-06-30 23:00          Good
# 670829  Visakhapatnam   2020-07-01 0:00          Good
#
# [670830 rows x 3 columns]

# %%
df_cat['col1'].value_counts()
# Out:
# Delhi                 48192
# Mumbai                46728
# Chennai               46728
# Bengaluru             46728
# Ahmedabad             46728
# Lucknow               46728
# Hyderabad             46643
# Patna                 44554
# Gurugram              38794
# Visakhapatnam         35053
# Amritsar              27805
# Jorapokhar            26561
# Jaipur                25241
# Thiruvananthapuram    25187
# Amaravati             22784
# Brajrajnagar          21004
# Talcher               20697
# Kolkata               18039
# Guwahati              12002
# Chandigarh             7263
# Shillong               5938
# Bhopal                 5439
# Kochi                  2390
# Ernakulam              2388
# Aizawl                 1216
# Name: col1, dtype: int64

# %%
df_cat['col16'].value_counts()
# Out:
# Moderate        190884
# Satisfactory    171473
# Poor             66425
# Very Poor        57448
# Good             31863
# Severe           27632
# Name: col16, dtype: int64

# %%
df_cat.mode()
# Out:
#        col1              col2     col16
# 0     Delhi  2020-03-11 10:00  Moderate
# 1       NaN  2020-03-11 11:00       NaN
# 2       NaN  2020-03-11 12:00       NaN
# 3       NaN  2020-03-11 13:00       NaN
# 4       NaN  2020-03-11 14:00       NaN
# ...     ...               ...       ...
# 1211    NaN   2020-04-30 6:00       NaN
# 1212    NaN   2020-04-30 7:00       NaN
# 1213    NaN   2020-04-30 8:00       NaN
# 1214    NaN   2020-04-30 9:00       NaN
# 1215    NaN   2020-05-01 0:00       NaN
#
# [1216 rows x 3 columns]

# %%
cat_modes = df_cat.mode().iloc[0,:]
print(cat_modes)
# Out:
# col1                Delhi
# col2     2020-03-11 10:00
# col16            Moderate
# Name: 0, dtype: object

# %%
df_cat.fillna(cat_modes)
# Out:
#                  col1              col2         col16
# 0           Ahmedabad   2015-01-01 1:00      Moderate
# 1           Ahmedabad   2015-01-01 2:00      Moderate
# 2           Ahmedabad   2015-01-01 3:00      Moderate
# 3           Ahmedabad   2015-01-01 4:00      Moderate
# 4           Ahmedabad   2015-01-01 5:00      Moderate
# ...               ...               ...           ...
# 670825  Visakhapatnam  2020-06-30 20:00  Satisfactory
# 670826  Visakhapatnam  2020-06-30 21:00  Satisfactory
# 670827  Visakhapatnam  2020-06-30 22:00          Good
# 670828  Visakhapatnam  2020-06-30 23:00          Good
# 670829  Visakhapatnam   2020-07-01 0:00          Good
#
# [670830 rows x 3 columns]

# %% [markdown]
# #### 실습
# * dataset_product.xlsx 데이터에서 다음에 따라 결측치를 처리하세요
# * 1. object일 경우 mode로 처리
# * 2. 연속형일 경우 평균으로 처리

# %%
df2 =  pd.read_excel('./Dataset/dataset_product.xlsx')

# %%
df2.dtypes
# Out:
# col1       object
# col2       object
# col3       object
# col4       object
# col5       object
#            ...
# col599      int64
# col600    float64
# col601     object
# col602     object
# col603    float64
# Length: 603, dtype: object

# %%
idx_col1 = df2.dtypes=='object'
idx_col2 = df2.dtypes=='float64'

# %%
df2_cat = df2.loc[:,idx_col1]
df2_contin = df2.loc[:,idx_col2]

# %%
df2_cat
# Out:
#          col1 col2 col3 col4   col5        col6         col8        col9  \
# 0     SB63856  생산량  11월  4분기  2019년   HBU096890  V77065L3XX1  HTSCC77HA1
# 1     SB63856  생산량  11월  4분기  2019년   HBU096880  V77065L3XX1  HTSCC77HA1
# 2     SB64098  생산량  10월  4분기  2019년  HBU114310A  V62078F5CR1  HTSCC62GA2
# 3     SB64098  생산량  10월  4분기  2019년   HBU114310  V62078F5CR1  HTSCC62GA2
# 4     SB64406  생산량  10월  4분기  2019년   HBU140120  V77040L5CR2  HTSCC77GA2
# ...       ...  ...  ...  ...    ...         ...          ...         ...
# 7074  SB84666  생산량  03월  1분기  2020년  HBC098990A  VA5040L3CR1  HTSCCA5HA2
# 7075  SB84666  생산량  03월  1분기  2020년   HBC098940  VA5040L3CR1  HTSCCA5HA2
# 7076  SB84666  생산량  03월  1분기  2020년   HBC098560  VA5040L3CR1  HTSCCA5HA2
# 7077  SB84666  생산량  03월  1분기  2020년   HBC098910  VA5040L3CR1  HTSCCA5HA2
# 7078  SB84666  생산량  03월  1분기  2020년   HBC098990  VA5040L3CR1  HTSCCA5HA2
#
#                 col15 col16  ...  col575     col578  \
# ...

# %%
df2_cat_modes = df2_cat.mode().iloc[0,:]
df2_cat_fill = df2_cat.fillna(df2_cat_modes)
df2_contin_fill = df2_contin.fillna(df2_contin.mean())
# RE2_fill = RE2.fillna(RE2.mode())
# RE3_fill = RE3.fillna(RE3.mean())

# %%
df2_fill = pd.concat([df2_cat_fill, df2_contin_fill], axis=1)

# %%
print(df2_fill)
# Out:
#          col1 col2 col3 col4   col5        col6         col8        col9  \
# 0     SB63856  생산량  11월  4분기  2019년   HBU096890  V77065L3XX1  HTSCC77HA1
# 1     SB63856  생산량  11월  4분기  2019년   HBU096880  V77065L3XX1  HTSCC77HA1
# 2     SB64098  생산량  10월  4분기  2019년  HBU114310A  V62078F5CR1  HTSCC62GA2
# 3     SB64098  생산량  10월  4분기  2019년   HBU114310  V62078F5CR1  HTSCC62GA2
# 4     SB64406  생산량  10월  4분기  2019년   HBU140120  V77040L5CR2  HTSCC77GA2
# ...       ...  ...  ...  ...    ...         ...          ...         ...
# 7074  SB84666  생산량  03월  1분기  2020년  HBC098990A  VA5040L3CR1  HTSCCA5HA2
# 7075  SB84666  생산량  03월  1분기  2020년   HBC098940  VA5040L3CR1  HTSCCA5HA2
# 7076  SB84666  생산량  03월  1분기  2020년   HBC098560  VA5040L3CR1  HTSCCA5HA2
# 7077  SB84666  생산량  03월  1분기  2020년   HBC098910  VA5040L3CR1  HTSCCA5HA2
# 7078  SB84666  생산량  03월  1분기  2020년   HBC098990  VA5040L3CR1  HTSCCA5HA2
#
#                 col15 col16  ... col579 col580 col581 col582 col586 col589  \
# ...

# %% [markdown]
# ### 3. Numpy

# %% [markdown]
# ###  3.1 행렬 살펴보기

# %%
df
# Out:
#                  col1              col2   col3   col4  col5   col6   col7  \
# 0           Ahmedabad   2015-01-01 1:00    NaN    NaN  1.00  40.01  36.37
# 1           Ahmedabad   2015-01-01 2:00    NaN    NaN  0.02  27.75  19.73
# 2           Ahmedabad   2015-01-01 3:00    NaN    NaN  0.08  19.32  11.08
# 3           Ahmedabad   2015-01-01 4:00    NaN    NaN  0.30  16.45   9.20
# 4           Ahmedabad   2015-01-01 5:00    NaN    NaN  0.12  14.90   7.85
# ...               ...               ...    ...    ...   ...    ...    ...
# 670825  Visakhapatnam  2020-06-30 20:00   9.50  36.00  2.75  25.57  15.85
# 670826  Visakhapatnam  2020-06-30 21:00  17.25  49.25  3.62  33.20  20.62
# 670827  Visakhapatnam  2020-06-30 22:00  36.00  71.00  2.20  30.80  18.20
# 670828  Visakhapatnam  2020-06-30 23:00  15.75  63.00  1.02  28.90  16.00
# 670829  Visakhapatnam   2020-07-01 0:00  15.00  66.00  0.40  26.85  14.05
#
#         col8  col9   col10   col11  col12  col13  col14  col15         col16
# ...

# %%
#df_np = df.to_numpy()
df_np= df.values

# %%
df
# Out:
#                  col1              col2   col3   col4  col5   col6   col7  \
# 0           Ahmedabad   2015-01-01 1:00    NaN    NaN  1.00  40.01  36.37
# 1           Ahmedabad   2015-01-01 2:00    NaN    NaN  0.02  27.75  19.73
# 2           Ahmedabad   2015-01-01 3:00    NaN    NaN  0.08  19.32  11.08
# 3           Ahmedabad   2015-01-01 4:00    NaN    NaN  0.30  16.45   9.20
# 4           Ahmedabad   2015-01-01 5:00    NaN    NaN  0.12  14.90   7.85
# ...               ...               ...    ...    ...   ...    ...    ...
# 670825  Visakhapatnam  2020-06-30 20:00   9.50  36.00  2.75  25.57  15.85
# 670826  Visakhapatnam  2020-06-30 21:00  17.25  49.25  3.62  33.20  20.62
# 670827  Visakhapatnam  2020-06-30 22:00  36.00  71.00  2.20  30.80  18.20
# 670828  Visakhapatnam  2020-06-30 23:00  15.75  63.00  1.02  28.90  16.00
# 670829  Visakhapatnam   2020-07-01 0:00  15.00  66.00  0.40  26.85  14.05
#
#         col8  col9   col10   col11  col12  col13  col14  col15         col16
# ...

# %%
df_np
# Out:
# array([['Ahmedabad', '2015-01-01 1:00', nan, ..., 0.0, nan, nan],
#        ['Ahmedabad', '2015-01-01 2:00', nan, ..., 0.0, nan, nan],
#        ['Ahmedabad', '2015-01-01 3:00', nan, ..., 0.0, nan, nan],
#        ...,
#        ['Visakhapatnam', '2020-06-30 22:00', 36.0, ..., nan, 50.0,
#         'Good'],
#        ['Visakhapatnam', '2020-06-30 23:00', 15.75, ..., nan, 50.0,
#         'Good'],
#        ['Visakhapatnam', '2020-07-01 0:00', 15.0, ..., nan, 50.0, 'Good']],
#       dtype=object)

# %%
type(df_np)
# Out:
# numpy.ndarray

# %%
# 행렬의 크기
df_np.shape
# Out:
# (670830, 16)

# %%
# 변수의 형태
df_np.dtype
# Out:
# dtype('O')

# %%
df_contin_np = df_contin.values

# %%
print(df_contin_np)
# Out:
# [[      nan       nan 1.000e+00 ... 0.000e+00 0.000e+00       nan]
#  [      nan       nan 2.000e-02 ... 0.000e+00 0.000e+00       nan]
#  [      nan       nan 8.000e-02 ... 0.000e+00 0.000e+00       nan]
#  ...
#  [3.600e+01 7.100e+01 2.200e+00 ...       nan       nan 5.000e+01]
#  [1.575e+01 6.300e+01 1.020e+00 ...       nan       nan 5.000e+01]
#  [1.500e+01 6.600e+01 4.000e-01 ...       nan       nan 5.000e+01]]

# %%
df_contin_np.dtype
# Out:
# dtype('float64')

# %%
df_contin_np.shape
# Out:
# (670830, 13)

# %%
df_contin_np
# Out:
# array([[      nan,       nan, 1.000e+00, ..., 0.000e+00, 0.000e+00,
#               nan],
#        [      nan,       nan, 2.000e-02, ..., 0.000e+00, 0.000e+00,
#               nan],
#        [      nan,       nan, 8.000e-02, ..., 0.000e+00, 0.000e+00,
#               nan],
#        ...,
#        [3.600e+01, 7.100e+01, 2.200e+00, ...,       nan,       nan,
#         5.000e+01],
#        [1.575e+01, 6.300e+01, 1.020e+00, ...,       nan,       nan,
#         5.000e+01],
#        [1.500e+01, 6.600e+01, 4.000e-01, ...,       nan,       nan,
#         5.000e+01]])

# %%
df_contin_np[0,2]
# Out:
# 1.0

# %%
df_contin_np[0,:5]
# Out:
# array([  nan,   nan,  1.  , 40.01, 36.37])

# %%
df_cat_np = df_cat.values

# %%
df_cat_np
# Out:
# array([['Ahmedabad', '2015-01-01 1:00', nan],
#        ['Ahmedabad', '2015-01-01 2:00', nan],
#        ['Ahmedabad', '2015-01-01 3:00', nan],
#        ...,
#        ['Visakhapatnam', '2020-06-30 22:00', 'Good'],
#        ['Visakhapatnam', '2020-06-30 23:00', 'Good'],
#        ['Visakhapatnam', '2020-07-01 0:00', 'Good']], dtype=object)

# %% [markdown]
# ### 3.2 조건에 맞는 행이나 열 선택,  최대, 최소, 행렬 붙이기,

# %%
df_contin_np
# Out:
# array([[      nan,       nan, 1.000e+00, ..., 0.000e+00, 0.000e+00,
#               nan],
#        [      nan,       nan, 2.000e-02, ..., 0.000e+00, 0.000e+00,
#               nan],
#        [      nan,       nan, 8.000e-02, ..., 0.000e+00, 0.000e+00,
#               nan],
#        ...,
#        [3.600e+01, 7.100e+01, 2.200e+00, ...,       nan,       nan,
#         5.000e+01],
#        [1.575e+01, 6.300e+01, 1.020e+00, ...,       nan,       nan,
#         5.000e+01],
#        [1.500e+01, 6.600e+01, 4.000e-01, ...,       nan,       nan,
#         5.000e+01]])

# %%
df_contin_np[:,1]
# Out:
# array([nan, nan, nan, ..., 71., 63., 66.])

# %%
# 첫번째 열이 2 이상인 행 선택
idx7 = df_contin_np[:,1]>=2

# %%
idx7
# Out:
# array([False, False, False, ...,  True,  True,  True])

# %%
idx_col1.array
# Out:
# <PandasArray>
# [ True,  True,  True,  True,  True,  True, False,  True,  True, False,
#  ...
#   True,  True,  True, False, False, False, False,  True,  True, False]
# Length: 603, dtype: bool

# %%
type(idx_col1.array)
# Out:
# pandas.core.arrays.numpy_.PandasArray

# %%
type(idx7)
# Out:
# numpy.ndarray

# %%
idx7
# Out:
# array([False, False, False, ...,  True,  True,  True])

# %%
df_contin_np[idx7,:]
# Out:
# array([[ 40.02, 120.06,  13.87, ...,  85.05,  13.26,    nan],
#        [ 39.29, 108.41,  17.95, ...,  84.22,  16.41,    nan],
#        [ 57.52, 153.03,  18.01, ...,  83.48,  10.64,    nan],
#        ...,
#        [ 36.  ,  71.  ,   2.2 , ...,    nan,    nan,  50.  ],
#        [ 15.75,  63.  ,   1.02, ...,    nan,    nan,  50.  ],
#        [ 15.  ,  66.  ,   0.4 , ...,    nan,    nan,  50.  ]])

# %%
df_contin_np.mean()
# Out:
# nan

# %%
print('전체 평균:',df_contin_np.mean()) # 전체 평균 출력
print('각 열별 평균:',df_contin_np.mean(0)) # 각 열별 평균 출력
print('각 행별 평균:',df_contin_np.mean(1))
# Out:
# 전체 평균: nan
# 각 열별 평균: [nan nan nan nan nan nan nan nan nan nan nan nan nan]
# 각 행별 평균: [nan nan nan ... nan nan nan]

# %%
print('전체 최소:',df_contin_np.min()) # 전체 평균 출력
print('각 열별 최소',df_contin_np.min(0)) # 각 열별 평균 출력
print('각 행별 최소:',df_contin_np.min(1))
# Out:
# 전체 최소: nan
# 각 열별 최소 [nan nan nan nan nan nan nan nan nan nan nan nan nan]
# 각 행별 최소: [nan nan nan ... nan nan nan]

# %%
# nan 무시
print('전체 평균(nan무시):',np.nanmean(df_contin_np)) # 전체 평균 출력
print('각 열별 평균(nan 무시):',np.nanmean(df_contin_np,0)) # 각 열별 평균 출력
print('각 행별 평균(nan 무시):',np.nanmean(df_contin_np,1))
# Out:
# 전체 평균(nan무시): 41.56496389319007
# 각 열별 평균(nan 무시): [ 70.06736366 124.03702445  17.81342348  29.58927888  32.95796941
#   24.2683775    2.26577333  14.31224418  34.8079538    3.12731016
#    8.92342244   3.14677558 171.58733611]
# 각 행별 평균(nan 무시): [25.05625 16.6775  10.42375 ... 24.037   19.553   19.724  ]

# %%
# nan 무시
print('전체 최소(nan무시):',np.nanmin(df_contin_np)) # 전체 평균 출력
print('각 열별 최소(nan 무시):',np.nanmin(df_contin_np,0)) # 각 열별 평균 출력
print('각 행별 최소(nan 무시):',np.nanmin(df_contin_np,1))
# Out:
# 전체 최소(nan무시): 0.0
# 각 열별 최소(nan 무시): [0.01 0.01 0.01 0.01 0.   0.01 0.   0.01 0.01 0.   0.   0.   9.  ]
# 각 행별 최소(nan 무시): [0.   0.   0.   ... 0.58 0.49 0.4 ]

# %% [markdown]
# #### 실습
#  전체, 각 열별, 각 행별 최대, 평균과 표준편차 (nan 무시)

# %%
df_contin_np
# Out:
# array([[      nan,       nan, 1.000e+00, ..., 0.000e+00, 0.000e+00,
#               nan],
#        [      nan,       nan, 2.000e-02, ..., 0.000e+00, 0.000e+00,
#               nan],
#        [      nan,       nan, 8.000e-02, ..., 0.000e+00, 0.000e+00,
#               nan],
#        ...,
#        [3.600e+01, 7.100e+01, 2.200e+00, ...,       nan,       nan,
#         5.000e+01],
#        [1.575e+01, 6.300e+01, 1.020e+00, ...,       nan,       nan,
#         5.000e+01],
#        [1.500e+01, 6.600e+01, 4.000e-01, ...,       nan,       nan,
#         5.000e+01]])

# %%
# nan 무시
print('전체 표준편차(nan무시):',np.nanstd(df_contin_np)) # 전체 평균 출력
print('각 열별 표준편차(nan 무시):',np.nanstd(df_contin_np,0)) # 각 열별 평균 출력
print('각 행별 표준편차(nan 무시):',np.nanstd(df_contin_np,1))
# Out:
# 전체 표준편차(nan무시): 80.32559358418293
# 각 열별 표준편차(nan 무시): [ 76.08449633 105.66332903  32.70245826  29.59343591  40.53685208
#   29.54583117  11.28662937  19.78878223  29.93055326  16.52523779
#   21.94807375   7.94475527 165.26175092]
# 각 행별 표준편차(nan 무시): [40.0064629  28.09144476 17.38466993 ... 22.46042522 20.61948062
#  21.05142237]

# %%
# nan 무시
print('전체 최대(nan무시):',np.nanmax(df_contin_np)) # 전체 평균 출력
print('각 열별 최대(nan 무시):',np.nanmax(df_contin_np,0)) # 각 열별 평균 출력
print('각 행별 최대(nan 무시):',np.nanmax(df_contin_np,1))
# Out:
# 전체 최대(nan무시): 3133.0
# 각 열별 최대(nan 무시): [ 999.99 1000.    499.99  499.51  498.61  499.97  498.57  199.96  497.62
#   498.07  499.4   499.99 3133.  ]
# 각 행별 최대(nan 무시): [122.07  85.9   52.83 ...  71.    63.    66.  ]

# %%
# 두 행렬을 세로로 이어 붙이기

df_np1 = df_contin_np[:3,:5]
df_np2 = df_contin_np[3:6,:5]

# %%
print(df_np1)
print(df_np1.shape)
# Out:
# [[      nan       nan 1.000e+00 4.001e+01 3.637e+01]
#  [      nan       nan 2.000e-02 2.775e+01 1.973e+01]
#  [      nan       nan 8.000e-02 1.932e+01 1.108e+01]]
# (3, 5)

# %%
print(df_np2)
print(df_np2.shape)
# Out:
# [[  nan   nan  0.3  16.45  9.2 ]
#  [  nan   nan  0.12 14.9   7.85]
#  [  nan   nan  0.33 15.95 10.82]]
# (3, 5)

# %%
df_np3=np.concatenate((df_np1,df_np2))
print(df_np3)
print(df_np3.shape)
# Out:
# [[      nan       nan 1.000e+00 4.001e+01 3.637e+01]
#  [      nan       nan 2.000e-02 2.775e+01 1.973e+01]
#  [      nan       nan 8.000e-02 1.932e+01 1.108e+01]
#  [      nan       nan 3.000e-01 1.645e+01 9.200e+00]
#  [      nan       nan 1.200e-01 1.490e+01 7.850e+00]
#  [      nan       nan 3.300e-01 1.595e+01 1.082e+01]]
# (6, 5)

# %%
# 두 행렬을 가로로 이어 붙이기
df_np4=np.concatenate((df_np1,df_np2), axis=1)
print(df_np4)
print(df_np4.shape)
# Out:
# [[      nan       nan 1.000e+00 4.001e+01 3.637e+01       nan       nan
#   3.000e-01 1.645e+01 9.200e+00]
#  [      nan       nan 2.000e-02 2.775e+01 1.973e+01       nan       nan
#   1.200e-01 1.490e+01 7.850e+00]
#  [      nan       nan 8.000e-02 1.932e+01 1.108e+01       nan       nan
#   3.300e-01 1.595e+01 1.082e+01]]
# (3, 10)

# %% [markdown]
# ## 4. Impute

# %% [markdown]
# ### 4.1 결측치 처리하기

# %%
# 결측치 확인하기
idx_missing=np.isnan(df_contin_np)
print(idx_missing)
# Out:
# [[ True  True False ... False False  True]
#  [ True  True False ... False False  True]
#  [ True  True False ... False False  True]
#  ...
#  [False False False ...  True  True False]
#  [False False False ...  True  True False]
#  [False False False ...  True  True False]]

# %%
print('전체 결측치의 개수:', np.isnan(df_contin_np).sum())
print('행별 결측치의 개수:', np.isnan(df_contin_np).sum(1))
print('열별 결측치의 개수:', np.isnan(df_contin_np).sum(0))
# Out:
# 전체 결측치의 개수: 2290978
# 행별 결측치의 개수: [5 5 5 ... 3 3 3]
# 열별 결측치의 개수: [139972 289899 112205 112895 119336 263630  84432 126939 123458 155246
#  210532 427329 125105]

# %%
df_contin_np.shape
# Out:
# (670830, 13)

# %%
# sklearn.impute에서 모두 불러오기
from sklearn.impute import *
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer

# %%
# ?SimpleImputer

# %%
# 평균으로 채워넣기
imp_mean = SimpleImputer(strategy='mean', missing_values=np.nan) 
# 1. 모형 선언,  결측치는 평균으로 채워넣고 결측치는 np.nan 값을 가지고
imp_mean.fit(df_contin_np)
# 2. 각 열별 평균을 EQ_contin_np 행렬을 기준으로 계산
# Out:
# SimpleImputer()

# %%
# 각 열의 fit된 평균값 출력
imp_mean.statistics_
# Out:
# array([ 70.06736366, 124.03702445,  17.81342348,  29.58927888,
#         32.95796941,  24.2683775 ,   2.26577333,  14.31224418,
#         34.8079538 ,   3.12731016,   8.92342244,   3.14677558,
#        171.58733611])

# %%
# 3. transform : statistics_에 저장된 값으로 결측치를 채워 넣겠다. 
print(imp_mean.transform(df_contin_np))
# Out:
# [[7.00673637e+01 1.24037024e+02 1.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 1.71587336e+02]
#  [7.00673637e+01 1.24037024e+02 2.00000000e-02 ... 0.00000000e+00
#   0.00000000e+00 1.71587336e+02]
#  [7.00673637e+01 1.24037024e+02 8.00000000e-02 ... 0.00000000e+00
#   0.00000000e+00 1.71587336e+02]
#  ...
#  [3.60000000e+01 7.10000000e+01 2.20000000e+00 ... 8.92342244e+00
#   3.14677558e+00 5.00000000e+01]
#  [1.57500000e+01 6.30000000e+01 1.02000000e+00 ... 8.92342244e+00
#   3.14677558e+00 5.00000000e+01]
#  [1.50000000e+01 6.60000000e+01 4.00000000e-01 ... 8.92342244e+00
#   3.14677558e+00 5.00000000e+01]]

# %%
# median으로 채워넣기
imp_median = SimpleImputer(strategy='median', missing_values=np.nan) # 선언, median으로 결측치를 채워 넣겠다
imp_median.fit(df_contin_np) # median 값을 학습
# Out:
# SimpleImputer(strategy='median')

# %%
imp_median.statistics_
# Out:
# array([ 48.5 ,  94.89,   8.08,  21.  ,  21.24,  15.9 ,   0.81,   8.4 ,
#         26.18,   0.92,   2.77,   0.78, 120.  ])

# %%
print(imp_median.transform(df_contin_np))
# Out:
# [[4.850e+01 9.489e+01 1.000e+00 ... 0.000e+00 0.000e+00 1.200e+02]
#  [4.850e+01 9.489e+01 2.000e-02 ... 0.000e+00 0.000e+00 1.200e+02]
#  [4.850e+01 9.489e+01 8.000e-02 ... 0.000e+00 0.000e+00 1.200e+02]
#  ...
#  [3.600e+01 7.100e+01 2.200e+00 ... 2.770e+00 7.800e-01 5.000e+01]
#  [1.575e+01 6.300e+01 1.020e+00 ... 2.770e+00 7.800e-01 5.000e+01]
#  [1.500e+01 6.600e+01 4.000e-01 ... 2.770e+00 7.800e-01 5.000e+01]]

# %%
df_contin.shape
# Out:
# (670830, 13)

# %%
# ?KNNImputer

# %%
df_contin_np2 = df_contin.sample(10000).to_numpy()

# %%
# knn으로 채워넣기
imp_KNN = KNNImputer(n_neighbors=5, missing_values=np.nan)
imp_KNN.fit(df_contin_np2)
print(imp_KNN.transform(df_contin_np2))
# Out:
# [[5.9000e+01 8.8474e+01 8.6800e+00 ... 1.2960e+01 9.0100e+00 1.5300e+02]
#  [4.3560e+01 1.1219e+02 5.2900e+00 ... 6.4100e+00 2.1000e-01 7.2000e+01]
#  [4.3250e+01 5.8412e+01 1.2260e+01 ... 1.8920e+01 1.6230e+01 8.0000e+01]
#  ...
#  [3.5380e+01 1.2218e+02 2.0170e+01 ... 1.1600e-01 1.4000e-02 3.1900e+02]
#  [7.4850e+01 1.2279e+02 1.2330e+01 ... 1.0540e+01 4.9000e-01 1.8100e+02]
#  [4.3020e+01 6.7274e+01 2.6320e+01 ... 1.2000e+01 1.2400e-01 9.2000e+01]]

# %%
# ?IterativeImputer

# %%
# IterativeImputer를 이용해서  채워넣기
imp_mice = IterativeImputer(missing_values=np.nan)
imp_mice.fit(df_contin_np2)
print(imp_mice.transform(df_contin_np2))
# Out:
# [[5.90000000e+01 1.17936753e+02 8.68000000e+00 ... 1.29600000e+01
#   9.01000000e+00 1.53000000e+02]
#  [4.35600000e+01 1.12190000e+02 5.29000000e+00 ... 6.41000000e+00
#   2.10000000e-01 7.20000000e+01]
#  [4.32500000e+01 9.70373189e+01 1.22600000e+01 ... 1.89200000e+01
#   1.62300000e+01 8.00000000e+01]
#  ...
#  [3.53800000e+01 1.22180000e+02 2.01700000e+01 ... 2.65866469e+01
#   5.05494868e+00 3.19000000e+02]
#  [7.48500000e+01 1.22790000e+02 1.23300000e+01 ... 1.05400000e+01
#   4.90000000e-01 1.81000000e+02]
#  [4.30200000e+01 9.46012059e+01 2.63200000e+01 ... 1.20000000e+01
#   5.64943327e+00 9.20000000e+01]]

# %% [markdown]
# #### 실습

# %%
df
# Out:
#                  col1              col2   col3   col4  col5   col6   col7  \
# 0           Ahmedabad   2015-01-01 1:00    NaN    NaN  1.00  40.01  36.37
# 1           Ahmedabad   2015-01-01 2:00    NaN    NaN  0.02  27.75  19.73
# 2           Ahmedabad   2015-01-01 3:00    NaN    NaN  0.08  19.32  11.08
# 3           Ahmedabad   2015-01-01 4:00    NaN    NaN  0.30  16.45   9.20
# 4           Ahmedabad   2015-01-01 5:00    NaN    NaN  0.12  14.90   7.85
# ...               ...               ...    ...    ...   ...    ...    ...
# 670825  Visakhapatnam  2020-06-30 20:00   9.50  36.00  2.75  25.57  15.85
# 670826  Visakhapatnam  2020-06-30 21:00  17.25  49.25  3.62  33.20  20.62
# 670827  Visakhapatnam  2020-06-30 22:00  36.00  71.00  2.20  30.80  18.20
# 670828  Visakhapatnam  2020-06-30 23:00  15.75  63.00  1.02  28.90  16.00
# 670829  Visakhapatnam   2020-07-01 0:00  15.00  66.00  0.40  26.85  14.05
#
#         col8  col9   col10   col11  col12  col13  col14  col15         col16
# ...

# %%
df_contin_np2
# Out:
# array([[5.9000e+01,        nan, 8.6800e+00, ..., 1.2960e+01, 9.0100e+00,
#         1.5300e+02],
#        [4.3560e+01, 1.1219e+02, 5.2900e+00, ..., 6.4100e+00, 2.1000e-01,
#         7.2000e+01],
#        [4.3250e+01,        nan, 1.2260e+01, ..., 1.8920e+01, 1.6230e+01,
#         8.0000e+01],
#        ...,
#        [3.5380e+01, 1.2218e+02, 2.0170e+01, ...,        nan,        nan,
#         3.1900e+02],
#        [7.4850e+01, 1.2279e+02, 1.2330e+01, ..., 1.0540e+01, 4.9000e-01,
#         1.8100e+02],
#        [4.3020e+01,        nan, 2.6320e+01, ..., 1.2000e+01,        nan,
#         9.2000e+01]])
